# %%
import pybamm
import numpy as np
import pickle

pybamm.set_logging_level("INFO")

data_DIR = "../data/"

# %%
# with open(data_DIR +'spm_old_fresh.pickle', 'rb') as handle:
#         spm_old = pickle.load(handle)
# with open(data_DIR +'dfn_old_fresh.pickle', 'rb') as handle:
#         dfn_old = pickle.load(handle)
with open(data_DIR +'spm_new_fresh.pickle', 'rb') as handle:
        spm_new = pickle.load(handle)
with open(data_DIR +'dfn_new_fresh.pickle', 'rb') as handle:
        dfn_new = pickle.load(handle)
